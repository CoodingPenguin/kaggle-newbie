# %% [markdown]
# # CNN with Keras by bgo - Third Try

# %% [markdown]
# ## 1. Create dataset

# %%
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# 데이터 로드
data_train = pd.read_csv('../data/fashion-mnist_train.csv')
data_test = pd.read_csv('../data/fashion-mnist_test.csv')

print('학습 데이터 크기 :', data_train.shape)
print('테스트 데이터 크기 :', data_train.shape)
# Out:
# 학습 데이터 크기 : (60000, 785)
# 테스트 데이터 크기 : (60000, 785)

# %%
# 입력과 라벨 데이터로 분리
X = np.array(data_train.iloc[:, 1:])
y = to_categorical(np.array(data_train.iloc[:, 0]))

# 테스트 데이터도 분리
X_test = np.array(data_test.iloc[:, 1:])
y_test = to_categorical(np.array(data_test.iloc[:, 0]))

# %%
# 학습/검증 데이터셋으로 분리
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# 입력 이미지의 크기
img_rows, img_cols = 28, 28
input_shape = (img_rows, img_cols, 1)

# 1차원 데이터를 2차원 이미지 데이터로 변환
X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
X_val = X_val.reshape(X_val.shape[0], img_rows, img_cols, 1)

# 0-1 사이의 값으로 정규화
X_train = X_train.astype('float32'); X_train /= 255
X_test = X_test.astype('float32'); X_test /=255
X_val = X_val.astype('float32'); X_val /= 255

# %%
# 최종 데이터의 크기
print('X_train의 크기 :', X_train.shape, ', X_val의 크기 :', X_val.shape, ', X_test의 크기 :', X_test.shape)
print('y_train의 크기 :', y_train.shape, ', y_val의 크기 :', y_val.shape, ', y_test의 크기 :', y_test.shape)
# Out:
# X_train의 크기 : (48000, 28, 28, 1) , X_val의 크기 : (12000, 28, 28, 1) , X_test의 크기 : (10000, 28, 28, 1)
# y_train의 크기 : (48000, 10) , y_val의 크기 : (12000, 10) , y_test의 크기 : (10000, 10)

# %% [markdown]
# ## 2. Modeling

# %%
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

# %%
# 파라미터 설정
batch_size = 256    # 배치 크기
num_classes=10      # 라벨 개수
epochs=50           # epoch 수

# %%
model = Sequential()

###################### 모델 설계 ######################
# Conv Layer 1
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',
                kernel_initializer='he_normal', input_shape=input_shape))
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

# Conv Layer 2
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Conv Layer 3
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Dropout(0.4))

# 데이터 평탄화
model.add(Flatten())

# Dense Layer 1
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))

# Dense Layer 2
model.add(Dense(num_classes, activation='softmax'))
#########################################################

# 모델 컴파일
# - 최적화 알고리즘: Adam
# - 비용 함수
model.compile(loss=keras.losses.categorical_crossentropy,
             optimizer=keras.optimizers.Adam(),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               147584
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 241,546
# Trainable params: 241,546
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 3. Training

# %%
# 모델 학습
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs,
                   verbose=1, validation_data=(X_val, y_val))
# 모델 성능 평가
score = model.evaluate(X_test, y_test, verbose=0)
# Out:
# Epoch 1/50
# 188/188 [==============================] - 12s 63ms/step - loss: 0.8002 - accuracy: 0.7015 - val_loss: 0.4980 - val_accuracy: 0.8173
# Epoch 2/50
# 188/188 [==============================] - 12s 63ms/step - loss: 0.5046 - accuracy: 0.8133 - val_loss: 0.4049 - val_accuracy: 0.8513
# Epoch 3/50
# 188/188 [==============================] - 12s 62ms/step - loss: 0.4312 - accuracy: 0.8422 - val_loss: 0.3513 - val_accuracy: 0.8723
# Epoch 4/50
# 188/188 [==============================] - 12s 63ms/step - loss: 0.3867 - accuracy: 0.8589 - val_loss: 0.3275 - val_accuracy: 0.8817
# Epoch 5/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.3572 - accuracy: 0.8687 - val_loss: 0.3038 - val_accuracy: 0.8910
# Epoch 6/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.3394 - accuracy: 0.8767 - val_loss: 0.2934 - val_accuracy: 0.8928
# Epoch 7/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.3206 - accuracy: 0.8815 - val_loss: 0.2820 - val_accuracy: 0.8977
# Epoch 8/50
# 188/188 [==============================] - 12s 66ms/step - loss: 0.3066 - accuracy: 0.8883 - val_loss: 0.2760 - val_accuracy: 0.9005
# Epoch 9/50
# 188/188 [==============================] - 12s 66ms/step - loss: 0.3009 - accuracy: 0.8896 - val_loss: 0.2675 - val_accuracy: 0.8997
# Epoch 10/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2899 - accuracy: 0.8937 - val_loss: 0.2620 - val_accuracy: 0.9043
# Epoch 11/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2842 - accuracy: 0.8959 - val_loss: 0.2622 - val_accuracy: 0.9043
# Epoch 12/50
# 188/188 [==============================] - 12s 66ms/step - loss: 0.2777 - accuracy: 0.8984 - val_loss: 0.2531 - val_accuracy: 0.9082
# Epoch 13/50
# 188/188 [==============================] - 12s 66ms/step - loss: 0.2694 - accuracy: 0.9009 - val_loss: 0.2446 - val_accuracy: 0.9081
# Epoch 14/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2610 - accuracy: 0.9046 - val_loss: 0.2436 - val_accuracy: 0.9121
# Epoch 15/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2581 - accuracy: 0.9055 - val_loss: 0.2379 - val_accuracy: 0.9107
# Epoch 16/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2569 - accuracy: 0.9046 - val_loss: 0.2369 - val_accuracy: 0.9126
# Epoch 17/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2487 - accuracy: 0.9078 - val_loss: 0.2343 - val_accuracy: 0.9153
# Epoch 18/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.2460 - accuracy: 0.9070 - val_loss: 0.2414 - val_accuracy: 0.9107
# Epoch 19/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2467 - accuracy: 0.9093 - val_loss: 0.2328 - val_accuracy: 0.9153
# Epoch 20/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2386 - accuracy: 0.9107 - val_loss: 0.2285 - val_accuracy: 0.9146
# Epoch 21/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2372 - accuracy: 0.9111 - val_loss: 0.2291 - val_accuracy: 0.9170
# Epoch 22/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.2320 - accuracy: 0.9130 - val_loss: 0.2269 - val_accuracy: 0.9167
# Epoch 23/50
# 188/188 [==============================] - 12s 66ms/step - loss: 0.2298 - accuracy: 0.9127 - val_loss: 0.2304 - val_accuracy: 0.9146
# Epoch 24/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2253 - accuracy: 0.9162 - val_loss: 0.2211 - val_accuracy: 0.9189
# Epoch 25/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2224 - accuracy: 0.9170 - val_loss: 0.2265 - val_accuracy: 0.9146
# Epoch 26/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2197 - accuracy: 0.9170 - val_loss: 0.2202 - val_accuracy: 0.9205
# Epoch 27/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.2189 - accuracy: 0.9175 - val_loss: 0.2238 - val_accuracy: 0.9194
# Epoch 28/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2140 - accuracy: 0.9193 - val_loss: 0.2261 - val_accuracy: 0.9174
# Epoch 29/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2128 - accuracy: 0.9191 - val_loss: 0.2234 - val_accuracy: 0.9181
# Epoch 30/50
# 188/188 [==============================] - 13s 70ms/step - loss: 0.2141 - accuracy: 0.9196 - val_loss: 0.2211 - val_accuracy: 0.9183
# Epoch 31/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2079 - accuracy: 0.9212 - val_loss: 0.2187 - val_accuracy: 0.9187
# Epoch 32/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.2115 - accuracy: 0.9208 - val_loss: 0.2191 - val_accuracy: 0.9177
# Epoch 33/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.2051 - accuracy: 0.9231 - val_loss: 0.2169 - val_accuracy: 0.9212
# Epoch 34/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2050 - accuracy: 0.9208 - val_loss: 0.2159 - val_accuracy: 0.9218
# Epoch 35/50
# 188/188 [==============================] - 13s 68ms/step - loss: 0.1972 - accuracy: 0.9252 - val_loss: 0.2183 - val_accuracy: 0.9208
# Epoch 36/50
# 188/188 [==============================] - 13s 66ms/step - loss: 0.1994 - accuracy: 0.9232 - val_loss: 0.2151 - val_accuracy: 0.9203
# Epoch 37/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1991 - accuracy: 0.9255 - val_loss: 0.2162 - val_accuracy: 0.9209
# Epoch 38/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.2006 - accuracy: 0.9242 - val_loss: 0.2223 - val_accuracy: 0.9172
# Epoch 39/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1942 - accuracy: 0.9274 - val_loss: 0.2149 - val_accuracy: 0.9226
# Epoch 40/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1963 - accuracy: 0.9254 - val_loss: 0.2142 - val_accuracy: 0.9220
# Epoch 41/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1936 - accuracy: 0.9252 - val_loss: 0.2185 - val_accuracy: 0.9210
# Epoch 42/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1941 - accuracy: 0.9268 - val_loss: 0.2174 - val_accuracy: 0.9190
# Epoch 43/50
# 188/188 [==============================] - 13s 70ms/step - loss: 0.1910 - accuracy: 0.9273 - val_loss: 0.2125 - val_accuracy: 0.9247
# Epoch 44/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1930 - accuracy: 0.9265 - val_loss: 0.2169 - val_accuracy: 0.9206
# Epoch 45/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1871 - accuracy: 0.9285 - val_loss: 0.2156 - val_accuracy: 0.9226
# Epoch 46/50
# 188/188 [==============================] - 13s 67ms/step - loss: 0.1872 - accuracy: 0.9295 - val_loss: 0.2142 - val_accuracy: 0.9218
# Epoch 47/50
# 188/188 [==============================] - 13s 70ms/step - loss: 0.1832 - accuracy: 0.9307 - val_loss: 0.2181 - val_accuracy: 0.9210
# Epoch 48/50
# 188/188 [==============================] - 13s 70ms/step - loss: 0.1867 - accuracy: 0.9287 - val_loss: 0.2173 - val_accuracy: 0.9223
# Epoch 49/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1855 - accuracy: 0.9291 - val_loss: 0.2184 - val_accuracy: 0.9208
# Epoch 50/50
# 188/188 [==============================] - 13s 69ms/step - loss: 0.1837 - accuracy: 0.9303 - val_loss: 0.2224 - val_accuracy: 0.9152

# %% [markdown]
# ## 4. Results

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 4.1. Accuracy and Loss

# %%
# 정확도
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# 손실함수의 값
loss = history.history['loss']
val_loss = history.history['val_loss']

# epoch 수
epochs = range(len(accuracy))

# %%
# epoch에 따른 정확도의 변화 시각화
plt.plot(epochs, accuracy, 'bo', label='training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %%
# epoch에 따른 손실함수의 값 변화 시각화
plt.plot(epochs, loss, 'bo', label='training loss')
plt.plot(epochs, val_loss, 'b', label='validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.2. Classification Report

# %%
# 테스트 데이터의 라벨 예측
predicted_classes = model.predict_classes(X_test)

# 맞춘/틀린 데이터의 인덱스 추출
y_true = data_test.iloc[:, 0]
corrects = np.where(predicted_classes==y_true)[0]
incorrects = np.where(predicted_classes!=y_true)[0]

# %%
from sklearn.metrics import classification_report

# 각 클래스별 정밀도, 재현율, F1스코어
target_names = ['Class {}'.format(i) for i in range(num_classes)]
print(classification_report(y_true, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.89      0.85      0.87      1000
#      Class 1       1.00      0.99      0.99      1000
#      Class 2       0.90      0.89      0.89      1000
#      Class 3       0.92      0.95      0.93      1000
#      Class 4       0.92      0.84      0.88      1000
#      Class 5       0.99      0.98      0.99      1000
#      Class 6       0.74      0.82      0.78      1000
#      Class 7       0.96      0.97      0.97      1000
#      Class 8       0.99      0.99      0.99      1000
#      Class 9       0.97      0.97      0.97      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.93      0.92      0.93     10000
# weighted avg       0.93      0.92      0.93     10000

# %%
# 맞춘 예측의 이미지 데이터를 시각화
for i, correct in enumerate(corrects[:9]):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_test[correct].reshape(28, 28), cmap='gray', interpolation='none')
    plt.title('Predicted {}, Class {}'.format(predicted_classes[correct], y_true[correct]))
    plt.tight_layout()

# %%
# 틀린 예측의 이미지 데이터를 시각화
for i, incorrect in enumerate(incorrects[:9]):
    plt.subplot(3, 3, i+1)
    plt.imshow(X_test[incorrect].reshape(28, 28), cmap='gray', interpolation='none')
    plt.title('Predicted {}, Class {}'.format(predicted_classes[incorrect], y_true[incorrect]))
    plt.tight_layout()

# %% [markdown]
# ### 4.3. What Activations Look Like

# %%
# 임의로 1개의 데이터 추출
test_im = X_train[154]
plt.imshow(test_im.reshape(28, 28), cmap='viridis', interpolation='none')
plt.show()

# %%
from tensorflow.keras import models

# Convolution Layer의 활성화 값만 뽑기 위해
# 학습된 모델의 완전연결계층 전까지의 Layer까지 추출
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activation_model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3_input (InputLayer)  [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3, 3, 128)         0
# =================================================================
# Total params: 92,672
# Trainable params: 92,672
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 입력 데이터 1개를 신경망에 흘려보냄
activations = activation_model.predict(test_im.reshape(1, 28, 28, 1))
# 첫 번째 Layer를 지나고 나서의 활성화 값
first_layer_activation = activations[0]
# 여러 개의 채널 중 3번째 채널의 활성화 값을 시각화
plt.matshow(first_layer_activation[0, :, :, 2], cmap='viridis')

# %%
print('activations의 개수 :', len(activations))
for i, activation in enumerate(activations):
    print(f'{i+1}번 째 activation의 크기 :', activation.shape)
# Out:
# activations의 개수 : 8
# 1번 째 activation의 크기 : (1, 26, 26, 32)
# 2번 째 activation의 크기 : (1, 13, 13, 32)
# 3번 째 activation의 크기 : (1, 13, 13, 32)
# 4번 째 activation의 크기 : (1, 11, 11, 64)
# 5번 째 activation의 크기 : (1, 5, 5, 64)
# 6번 째 activation의 크기 : (1, 5, 5, 64)
# 7번 째 activation의 크기 : (1, 3, 3, 128)
# 8번 째 activation의 크기 : (1, 3, 3, 128)

# %%
layer_names = []
# 마지막 Dense 층 빼고 Layer 이름 추출
for layer in model.layers[:-1]:
    layer_names.append(layer.name)
layer_names
# Out:
# ['conv2d_3',
#  'max_pooling2d_2',
#  'dropout_4',
#  'conv2d_4',
#  'max_pooling2d_3',
#  'dropout_5',
#  'conv2d_5',
#  'dropout_6',
#  'flatten_1',
#  'dense_2',
#  'dropout_7']

# %%
images_per_row = 16    # 한 줄당 시각화할 이미지 개수
for layer_name, layer_activation in zip(layer_names, activations):
    if layer_name.startswith('conv'):
        n_features = layer_activation.shape[-1]     # 필터 개수
        size = layer_activation.shape[1]            # Layer 통과 후 이미지 크기
        n_cols = n_features // images_per_row       # plot시의 row 개수
        
        # 전체 figure의 크기를 구해 해당 크기의 0으로 된 배열로 생성
        display_grid = np.zeros((size*n_cols, images_per_row*size))
        
        # 활성화값을 정규화하고 결과 값을 display_grid에 저장
        for col in range(n_cols):
            for row in range(images_per_row):
                channel_image = layer_activation[0, :, :, col*images_per_row+row]
                channel_image -= channel_image.mean()
                channel_image *= 64
                channel_image += 128
                channel_image = np.clip(channel_image, 0, 255).astype('uint8')
                
                display_grid[col*size:(col+1)*size, row*size:(row+1)*size] = channel_image
        
        # 모든 필터의 활성화 값 시각화
        scale = 1. / size
        plt.figure(figsize=(scale * display_grid.shape[1],
                            scale * display_grid.shape[0]))
        plt.title(layer_name)
        plt.grid(False)
        plt.imshow(display_grid, aspect='auto', cmap='viridis')
